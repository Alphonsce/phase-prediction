# %%
import os
import rootutils
import pandas as pd
import random
import numpy as np

import matplotlib.pyplot as plt

from tqdm.auto import tqdm
tqdm.pandas()

rootutils.setup_root(os.path.abspath('./'), indicator=".project-root", pythonpath=True, dotenv=True, cwd=True)

# auto-loading of imports from outside scripts
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from src.cif_utils import cif_from_file

# %%
meta_csv = "data_cod/cod_bradley_merged.csv"
cifs_dir = "cifs"

# %%
meta_df = pd.read_csv(meta_csv).drop_duplicates().sort_values(by="id")
meta_df["cif_path"] = cifs_dir + "/" + meta_df["id"].astype(str) + ".cif"

# %% [markdown]
# ---
# ## Coordinational Numbers:

# %%
from pymatgen.core import Structure
import numpy as np
import pandas as pd
from collections import defaultdict

from src.cif_utils import get_fixed_length_descriptor
from src.__cutoffs import cutoffs_gpt as cutoffs

# %%
result_cn_path = "coord_numbs.csv"
if os.path.exists(result_cn_path):
    cn_df = pd.read_csv(result_cn_path)
else:
    cn_df = pd.DataFrame()

error_cifs = [] 
save_every = 5

for i, cif_path in tqdm(enumerate(meta_df["cif_path"]), total=len(meta_df), desc="Processing CIFs"):
    try:
        coord_numbs = get_fixed_length_descriptor(
            cif_path,
            cutoffs,
            use_interior=True,
            struct_repeat=(2, 2, 2)
        )
        
        # Add to dataframe
        row_data = {"id": meta_df.iloc[i]['id'], "smiles": meta_df.iloc[i]['can_smiles']}
        row_data.update(coord_numbs.to_dict())
        cn_df = pd.concat([cn_df, pd.DataFrame([row_data])], ignore_index=True)
        
    except Exception as e:
        print(f"Error: {e}")
        error_cifs.append(cif_path)
    
    # Save results every k iterations
    if (i + 1) % save_every == 0:
        cn_df.to_csv(result_cn_path, index=False, float_format="%.3f")
        print(f"Saved results at iteration {i+1}")
    
    print(coord_numbs)
    print(f"smiles: {meta_df.iloc[i]['can_smiles']}")
    if i >= 20:
        break

# Save final results
if os.path.exists(result_cn_path):
    cn_df.to_csv(result_cn_path, index=False, float_format="%.3f")
# Out:
# Processing CIFs:   0%|          | 0/13528 [00:00<?, ?it/s]
# Ag–Ag    0.0
# Ag–H     0.0
# H–Ag     0.0
# Al–Al    0.0
# Al–H     0.0
#         ...
# H–Tl     0.0
# Tl–Tl    0.0
# Zn–H     0.0
# H–Zn     0.0
# Zn–Zn    0.0
# Name: avg_cn_descriptor, Length: 152, dtype: float64
# smiles: CC1(C)[C@@H]2CC[C@]3(C2)[C@H](O)CC[C@@H](O)[C@]13O.CC1(C)[C@H]2CC[C@@]3(C2)[C@@H](O)CC[C@H](O)[C@@]13O
# Ag–Ag    0.0
# Ag–H     0.0
# H–Ag     0.0
# Al–Al    0.0
# Al–H     0.0
#         ...
# H–Tl     0.0
# Tl–Tl    0.0
# Zn–H     0.0
# H–Zn     0.0
# Zn–Zn    0.0
# Name: avg_cn_descriptor, Length: 152, dtype: float64
# smiles: CN(C)c1ccc(/C=C/C(=O)c2ccccc2O)cc1
# Ag–Ag    0.0
# Ag–H     0.0
# H–Ag     0.0
# Al–Al    0.0
# Al–H     0.0
#         ...
# H–Tl     0.0
# Tl–Tl    0.0
# Zn–H     0.0
# H–Zn     0.0
# Zn–Zn    0.0
# Name: avg_cn_descriptor, Length: 152, dtype: float64
# smiles: OO
# Ag–Ag    0.0
# Ag–H     0.0
# H–Ag     0.0
# Al–Al    0.0
# Al–H     0.0
#         ...
# H–Tl     0.0
# Tl–Tl    0.0
# Zn–H     0.0
# H–Zn     0.0
# Zn–Zn    0.0
# Name: avg_cn_descriptor, Length: 152, dtype: float64
# smiles: NC(N)=O
# Saved results at iteration 5
# Ag–Ag    0.0
# Ag–H     0.0
# H–Ag     0.0
# Al–Al    0.0
# Al–H     0.0
#         ...
# H–Tl     0.0
# Tl–Tl    0.0
# Zn–H     0.0
# H–Zn     0.0
# Zn–Zn    0.0
# Name: avg_cn_descriptor, Length: 152, dtype: float64
# smiles: NC(N)=O
# Ag–Ag    0.0
# Ag–H     0.0
# H–Ag     0.0
# Al–Al    0.0
# Al–H     0.0
#         ...
# H–Tl     0.0
# Tl–Tl    0.0
# Zn–H     0.0
# H–Zn     0.0
# Zn–Zn    0.0
# Name: avg_cn_descriptor, Length: 152, dtype: float64
# smiles: NC(N)=O
# Ag–Ag    0.0
# Ag–H     0.0
# H–Ag     0.0
# Al–Al    0.0
# Al–H     0.0
#         ...
# H–Tl     0.0
# Tl–Tl    0.0
# Zn–H     0.0
# H–Zn     0.0
# Zn–Zn    0.0
# Name: avg_cn_descriptor, Length: 152, dtype: float64
# smiles: NC(N)=O
# Ag–Ag    0.0
# Ag–H     0.0
# H–Ag     0.0
# Al–Al    0.0
# Al–H     0.0
#         ...
# H–Tl     0.0
# Tl–Tl    0.0
# Zn–H     0.0
# H–Zn     0.0
# Zn–Zn    0.0
# Name: avg_cn_descriptor, Length: 152, dtype: float64
# smiles: NC(N)=O
# Ag–Ag    0.0
# Ag–H     0.0
# H–Ag     0.0
# Al–Al    0.0
# Al–H     0.0
#         ...
# H–Tl     0.0
# Tl–Tl    0.0
# Zn–H     0.0
# H–Zn     0.0
# Zn–Zn    0.0
# Name: avg_cn_descriptor, Length: 152, dtype: float64
# smiles: O=C=O
# Saved results at iteration 10
# Ag–Ag    0.0
# Ag–H     0.0
# H–Ag     0.0
# Al–Al    0.0
# Al–H     0.0
#         ...
# H–Tl     0.0
# Tl–Tl    0.0
# Zn–H     0.0
# H–Zn     0.0
# Zn–Zn    0.0
# Name: avg_cn_descriptor, Length: 152, dtype: float64
# smiles: ClCl
# Ag–Ag    0.0
# Ag–H     0.0
# H–Ag     0.0
# Al–Al    0.0
# Al–H     0.0
#         ...
# H–Tl     0.0
# Tl–Tl    0.0
# Zn–H     0.0
# H–Zn     0.0
# Zn–Zn    0.0
# Name: avg_cn_descriptor, Length: 152, dtype: float64
# smiles: II
# Ag–Ag    0.0
# Ag–H     0.0
# H–Ag     0.0
# Al–Al    0.0
# Al–H     0.0
#         ...
# H–Tl     0.0
# Tl–Tl    0.0
# Zn–H     0.0
# H–Zn     0.0
# Zn–Zn    0.0
# Name: avg_cn_descriptor, Length: 152, dtype: float64
# smiles: BrBr
# Ag–Ag    0.0
# Ag–H     0.0
# H–Ag     0.0
# Al–Al    0.0
# Al–H     0.0
#         ...
# H–Tl     0.0
# Tl–Tl    0.0
# Zn–H     0.0
# H–Zn     0.0
# Zn–Zn    0.0
# Name: avg_cn_descriptor, Length: 152, dtype: float64
# smiles: O=C=O
# Ag–Ag    0.0
# Ag–H     0.0
# H–Ag     0.0
# Al–Al    0.0
# Al–H     0.0
#         ...
# H–Tl     0.0
# Tl–Tl    0.0
# Zn–H     0.0
# H–Zn     0.0
# Zn–Zn    0.0
# Name: avg_cn_descriptor, Length: 152, dtype: float64
# smiles: ClCl
# Error: Invalid CIF file with no structures!
# Saved results at iteration 15
# Ag–Ag    0.0
# Ag–H     0.0
# H–Ag     0.0
# Al–Al    0.0
# Al–H     0.0
#         ...
# H–Tl     0.0
# Tl–Tl    0.0
# Zn–H     0.0
# H–Zn     0.0
# Zn–Zn    0.0
# Name: avg_cn_descriptor, Length: 152, dtype: float64
# smiles: ClP(Cl)(Cl)(Cl)Cl
# Error: Invalid CIF file with no structures!
# Ag–Ag    0.0
# Ag–H     0.0
# H–Ag     0.0
# Al–Al    0.0
# Al–H     0.0
#         ...
# H–Tl     0.0
# Tl–Tl    0.0
# Zn–H     0.0
# H–Zn     0.0
# Zn–Zn    0.0
# Name: avg_cn_descriptor, Length: 152, dtype: float64
# smiles: O
# Ag–Ag    0.0
# Ag–H     0.0
# H–Ag     0.0
# Al–Al    0.0
# Al–H     0.0
#         ...
# H–Tl     0.0
# Tl–Tl    0.0
# Zn–H     0.0
# H–Zn     0.0
# Zn–Zn    0.0
# Name: avg_cn_descriptor, Length: 152, dtype: float64
# smiles: ClCl
# Ag–Ag    0.0
# Ag–H     0.0
# H–Ag     0.0
# Al–Al    0.0
# Al–H     0.0
#         ...
# H–Tl     0.0
# Tl–Tl    0.0
# Zn–H     0.0
# H–Zn     0.0
# Zn–Zn    0.0
# Name: avg_cn_descriptor, Length: 152, dtype: float64
# smiles: O=C=O
# /home/aleksandr.varlamov/phase-prediction/.venv/lib/python3.10/site-packages/pymatgen/io/cif.py:1312: UserWarning: Some occupancies ([4.5]) sum to > 1! If they are within the occupancy_tolerance, they will be rescaled. The current occupancy_tolerance is set to: 1.0
#   if struct := self._get_structure(data, primitive, symmetrized, check_occu=check_occu):
# /home/aleksandr.varlamov/phase-prediction/.venv/lib/python3.10/site-packages/pymatgen/core/structure.py:3100: UserWarning: No structure parsed for section 1 in CIF.
# Occupancy 4.5 exceeded tolerance.
#   struct = parser.parse_structures(primitive=primitive)[0]
# /home/aleksandr.varlamov/phase-prediction/.venv/lib/python3.10/site-packages/pymatgen/core/structure.py:3100: UserWarning: Issues encountered while parsing CIF: Some occupancies ([4.5]) sum to > 1! If they are within the occupancy_tolerance, they will be rescaled. The current occupancy_tolerance is set to: 1.0
# No structure parsed for section 1 in CIF.
# Occupancy 4.5 exceeded tolerance.
#   struct = parser.parse_structures(primitive=primitive)[0]
# /home/aleksandr.varlamov/phase-prediction/.venv/lib/python3.10/site-packages/pymatgen/io/cif.py:1027: UserWarning: No _symmetry_equiv_pos_as_xyz type key found. Defaulting to P1.
#   self.symmetry_operations = self.get_symops(data)
# /home/aleksandr.varlamov/phase-prediction/.venv/lib/python3.10/site-packages/pymatgen/core/structure.py:3100: UserWarning: Issues encountered while parsing CIF: No _symmetry_equiv_pos_as_xyz type key found. Defaulting to P1.
#   struct = parser.parse_structures(primitive=primitive)[0]
# Ag–Ag    0.0
# Ag–H     0.0
# H–Ag     0.0
# Al–Al    0.0
# Al–H     0.0
#         ...
# H–Tl     0.0
# Tl–Tl    0.0
# Zn–H     0.0
# H–Zn     0.0
# Zn–Zn    0.0
# Name: avg_cn_descriptor, Length: 152, dtype: float64
# smiles: O=C=O
# Saved results at iteration 20
# Ag–Ag    0.0
# Ag–H     0.0
# H–Ag     0.0
# Al–Al    0.0
# Al–H     0.0
#         ...
# H–Tl     0.0
# Tl–Tl    0.0
# Zn–H     0.0
# H–Zn     0.0
# Zn–Zn    0.0
# Name: avg_cn_descriptor, Length: 152, dtype: float64
# smiles: O=C=O
# Ag–Ag    0.0
# Ag–H     0.0
# H–Ag     0.0
# Al–Al    0.0
# Al–H     0.0
#         ...
# H–Tl     0.0
# Tl–Tl    0.0
# Zn–H     0.0
# H–Zn     0.0
# Zn–Zn    0.0
# Name: avg_cn_descriptor, Length: 152, dtype: float64
# smiles: O=C=O
