# %%
import os
from datasets import Dataset, DatasetDict, Features, Value
from huggingface_hub import login, list_repo_files
from tqdm import tqdm

from functools import partial

# %%
TOKEN = "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"
login(token=TOKEN)

# %% [markdown]
# ---
# ## Loading:

# %%
from datasets import load_dataset

# %%
repo_name = "Alphonsce/cif-dataset"

# %%
all_files = list_repo_files(repo_name, repo_type="dataset", token=TOKEN)

# Filter for Parquet files
parquet_files = sorted([f for f in all_files if f.endswith(".parquet")])

# %%
dataset = load_dataset(
        repo_name, 
        data_files={
            "train": parquet_files[100:101]},
        token=TOKEN,
        split="train",
)
# Out:
# Generating train split:   0%|          | 0/1000 [00:00<?, ? examples/s]

# %%
# Get the content from the dataset
cif_content = dataset[0]["content"]

# Write the content to a CIF file
with open("output.cif", "w") as f:
    f.write(cif_content)

print(f"CIF file saved as 'output.cif'")

# Display the first few lines of the content
cif_content[:500] + "..."
# Out:
# CIF file saved as 'output.cif'
# '#------------------------------------------------------------------------------\n#$Date: 2018-11-03 22:30:44 +0200 (Sat, 03 Nov 2018) $\n#$Revision: 211790 $\n#$URL: file:///home/coder/svn-repositories/cod/cif/2/02/12/2021241.cif $\n#------------------------------------------------------------------------------\n#\n# This file is available in the Crystallography Open Database (COD),\n# http://www.crystallography.net/. The original data for this entry\n# were provided by IUCr Journals, http://journals.iu...'
