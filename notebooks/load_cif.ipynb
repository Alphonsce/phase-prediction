# %%
from typing import Tuple, List

import os
import rootutils

from tqdm import tqdm

rootutils.setup_root(os.path.abspath('./'), indicator=".project-root", pythonpath=True, dotenv=True, cwd=True)

# auto-loading of imports from outside scripts
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from rdkit import Chem
import pandas as pd
import pubchempy as pcp

from src.utils import create_df
from src.cif_utils import get_canonical_smiles, get_smiles_from_chemical_name, read_cif, get_smiles_from_id_on_web

# %% [markdown]
# ---

# %%
get_smiles_from_chemical_name("aspirin")
# Out:
# SMILES for aspirin: CC(=O)OC1=CC=CC=C1C(=O)O

# %%
data_path = "data/Bradley_dataset_ok_3"
columns = ['line_number', 'smiles', 'cas', 'label', 'T']

df = create_df(data_path, columns)
df = df.drop(columns=['cas'])

# %%
df = df.progress_apply(get_canonical_smiles, axis=1)
# Out:
#   0%|          | 0/25744 [00:00<?, ?it/s]

# %% [markdown]
# ---

# %%
# Example usage
cod_id = '7050897'
smiles = get_smiles_from_id_on_web(cod_id)
print(f"SMILES for COD ID {cod_id}: {smiles}")
# Out:
# SMILES for COD ID 7050897: c1(c(cccc1)OC(=O)C)C(=O)O
